# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %% [markdown]
# From the analysis in my amazon_data_analysis.ipynb notebook, I determined item 0439023513 is a typical review-distributed product with a large number of reviews. I will use this item for conducting my sample size analysis. It's average rating is 4.233, that is important information for later.
#
# Using the z-score table from https://www.sheffield.ac.uk/polopoly_fs/1.43999!/file/tutorial-10-reading-tables.pdf for my analysis.

# %%
amazon_reviews_df = pd.read_csv(r'rough_data\amazon_dataset\amzn_all_items_simplified.csv')

# %%
amazon_reviews_df
# Out:
#                 item  rating
# 0         0000000078     5.0
# 1         0000000116     4.0
# 2         0000000116     1.0
# 3         0000000868     4.0
# 4         0000013714     4.0
# ...              ...     ...
# 82677126  BT00IU6O8K     3.0
# 82677127  BT00IU6O8K     5.0
# 82677128  dp-g310/do     5.0
# 82677129  SMLRBIMX03     5.0
# 82677130  SMLRBIMX03     4.0
#
# [82677131 rows x 2 columns]

# %%
sample_item = '0439023513'
sample_item_df = amazon_reviews_df[amazon_reviews_df['item'] == sample_item]
sample_item_df
# Out:
#                item  rating
# 5521956  0439023513     4.0
# 5521957  0439023513     5.0
# 5521958  0439023513     5.0
# 5521959  0439023513     5.0
# 5521960  0439023513     5.0
# ...             ...     ...
# 5536065  0439023513     5.0
# 5536066  0439023513     1.0
# 5536067  0439023513     5.0
# 5536068  0439023513     5.0
# 5536069  0439023513     2.0
#
# [14114 rows x 2 columns]

# %%
# Commented this line out, only need it to run it once ever.
# sample_item_df.to_csv(r'rough_data\amazon_dataset\amzn_confidence_interval_dataset.csv', index=False)

# %%
sample_item_df['item'].value_counts()
# Out:
# 0439023513    14114
# Name: item, dtype: int64

# %% [markdown]
# The dataframe is indeed the one I was trying to create.

# %%
def sample_data_creation(num_ratings, num_samples, series_in=sample_item_df['rating']):
    '''
    Sample reviews from the population of reviews for a specific product.
    Default values are set for use with item 0439023153 (the intended use for the 
    function), but can be changed if needed.
    
    Inputs:
    num_ratings: Integer, the number of reviews in the output sample.
    num_samples: Integer, the number of samples in the output
    series_in: Input data
    '''
    output_list=[]
    for sample_number in range(num_samples): 
        review_subset = np.random.choice(series_in, num_ratings, replace=False)
        avg = review_subset.mean()
        output_list.append(avg)
    series_out = pd.Series(output_list)
    return series_out

# %%
num_ratings = 25
sample_series25 = sample_data_creation(num_ratings,5000)
plt.hist(sample_series25, bins=38, density=False, range=(3.3,4.8))
plt.title(f'Sample Average Rating Distribution\nFor Ratings/Sample of {num_ratings}', fontsize=16)
plt.xlabel('Sample Average Rating')
plt.ylabel('Frequency')

# Standard dev of the samples
std = np.std(sample_series25)
# z-score for 90% confidence interval
z_score = 1.645
ci_range = z_score * std
print('90% Confident that the real product average lies within \n+-', \
      round(ci_range,2),f'from the observed average when the sample size is {num_ratings}')
# Out:
# 90% Confident that the real product average lies within
# +- 0.37 from the observed average when the sample size is 25

# %%
num_ratings = 50
sample_series50 = sample_data_creation(num_ratings,5000)
plt.hist(sample_series50, bins=38, density=False, range=(3.3,4.8))
plt.title(f'Sample Average Rating Distribution\nFor Ratings/Sample of {num_ratings}', fontsize=16)
plt.xlabel('Sample Average Rating')
plt.ylabel('Frequency')

# Standard dev of the samples
std = np.std(sample_series50)
# z-score for 90% confidence interval
z_score = 1.645
ci_range = z_score * std
print('90% Confident that the real product average lies within \n+-', \
      round(ci_range,2),f'from the observed average when the sample size is {num_ratings}')
# Out:
# 90% Confident that the real product average lies within
# +- 0.26 from the observed average when the sample size is 50

# %%
num_ratings = 75
sample_series75 = sample_data_creation(num_ratings,5000)
plt.hist(sample_series75, bins=38, density=False, range=(3.3,4.8))
plt.title(f'Sample Average Rating Distribution\nFor Ratings/Sample of {num_ratings}', fontsize=16)
plt.xlabel('Sample Average Rating')
plt.ylabel('Frequency')

# Standard dev of the samples
std = np.std(sample_series75)
# z-score for 90% confidence interval
z_score = 1.645
ci_range = z_score * std
print('90% Confident that the real product average lies within \n+-', \
      round(ci_range,2),f'from the observed average when the sample size is {num_ratings}')
# Out:
# 90% Confident that the real product average lies within
# +- 0.22 from the observed average when the sample size is 75

# %%
num_ratings = 100
sample_series100 = sample_data_creation(num_ratings,5000)
plt.hist(sample_series100, bins=45, density=False, range=(3.3,4.8))
plt.title(f'Sample Average Rating Distribution\nFor Ratings/Sample of {num_ratings}', fontsize=16)
plt.xlabel('Sample Average Rating')
plt.ylabel('Frequency')

# Standard dev of the samples
std = np.std(sample_series100)
# z-score for 90% confidence interval
z_score = 1.645
ci_range = z_score * std
print('90% Confident that the real product average lies within \n+-', \
      round(ci_range,2),f'from the observed average when the sample size is {num_ratings}')
# Out:
# 90% Confident that the real product average lies within
# +- 0.19 from the observed average when the sample size is 100

# %%
num_ratings = 150
sample_series150 = sample_data_creation(num_ratings,5000)
plt.hist(sample_series150, bins=38, density=False, range=(3.3,4.8))
plt.title(f'Sample Average Rating Distribution\nFor Ratings/Sample of {num_ratings}', fontsize=16)
plt.xlabel('Sample Average Rating')
plt.ylabel('Frequency')

# Standard dev of the samples
std = np.std(sample_series150)
# z-score for 90% confidence interval
z_score = 1.645
ci_range = z_score * std
print('90% Confident that the real product average lies within \n+-', \
      round(ci_range,2),f'from the observed average when the sample size is {num_ratings}')
# Out:
# 90% Confident that the real product average lies within
# +- 0.15 from the observed average when the sample size is 150

# %%
num_ratings = 200
sample_series200 = sample_data_creation(num_ratings,5000)
plt.hist(sample_series200, bins=45, density=False, range=(3.3,4.8))
plt.title(f'Sample Average Rating Distribution\nFor Ratings/Sample of {num_ratings}', fontsize=16)
plt.xlabel('Sample Average Rating')
plt.ylabel('Frequency')

# Standard dev of the samples
std = np.std(sample_series200)
# z-score for 90% confidence interval
z_score = 1.645
ci_range = z_score * std
print('90% Confident that the real product average lies within \n+-', \
      round(ci_range,2),f'from the observed average when the sample size is {num_ratings}')
# Out:
# 90% Confident that the real product average lies within
# +- 0.13 from the observed average when the sample size is 200

# %%
num_ratings = 300
sample_series300 = sample_data_creation(num_ratings,5000)
plt.hist(sample_series300, bins=38, density=False, range=(3.3,4.8))
plt.title(f'Sample Average Rating Distribution\nFor Ratings/Sample of {num_ratings}', fontsize=16)
plt.xlabel('Sample Average Rating')
plt.ylabel('Frequency')

# Standard dev of the samples
std = np.std(sample_series300)
# z-score for 90% confidence interval
z_score = 1.645
ci_range = z_score * std
print('90% Confident that the real product average lies within \n+-', \
      round(ci_range,2),f'from the observed average when the sample size is {num_ratings}')
# Out:
# 90% Confident that the real product average lies within
# +- 0.11 from the observed average when the sample size is 300

# %%
import seaborn as sns
fig = plt.figure(figsize=(12,12))
fig.subplots_adjust(hspace=0.25, wspace=0.05)
ax = fig.add_subplot(2, 2, 1)  # Start Plot 1
sns.distplot(sample_series25, bins=38, ax=ax)
ax.set_xlim(3.3,4.8)
ax.set_title('Sample Average Rating Distribution\nFor Ratings/Sample of 25', fontsize=16)
ax.set_xlabel('')
ax.set_ylabel('')
ax.tick_params(axis='y', which='both', left=False, right=False, labelleft=False)
ax = fig.add_subplot(2, 2, 2) # Start Plot 2
sns.distplot(sample_series75, bins=38, ax=ax)
ax.set_xlim(3.3,4.8)
ax.set_title('Sample Average Rating Distribution\nFor Ratings/Sample of 75', fontsize=16)
ax.set_xlabel('')
ax.set_ylabel('')
ax.tick_params(axis='y', which='both', left=False, right=False, labelleft=False)
ax = fig.add_subplot(2, 2, 3) # Start Plot 3
sns.distplot(sample_series150, bins=38, ax=ax)
ax.set_xlim(3.3,4.8)
ax.set_title('Sample Average Rating Distribution\nFor Ratings/Sample of 150', fontsize=16)
ax.set_xlabel('Sample Average Rating', fontsize=14)
ax.set_ylabel('')
ax.tick_params(axis='y', which='both', left=False, right=False, labelleft=False)
ax = fig.add_subplot(2, 2, 4) # Start Plot 4
sns.distplot(sample_series300, bins=38, ax=ax)
ax.set_xlim(3.3,4.8)
ax.set_title('Sample Average Rating Distribution\nFor Ratings/Sample of 300', fontsize=16)
ax.set_xlabel('Sample Average Rating', fontsize=14)
ax.set_ylabel('')
ax.tick_params(axis='y', which='both', left=False, right=False, labelleft=False)
#plt.show()

plt.savefig('sample_averages.png')
plt.savefig('sample_averages.pdf')
plt.savefig('sample_averages.jpg')
# Out:
# C:\Users\ryanb\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\ryanb\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
plt.style.use('ggplot')
num_ratings = 300
sample_series = sample_data_creation(num_ratings,5000)
plt.hist(sample_series, bins=75, density=True, range=(1.0, 5.0), color='blue')
plt.title(f'Sample Average Rating Distribution\nFor Ratings/Sample of {num_ratings}', fontsize=16)
plt.xlabel('Sample Average Rating')
plt.ylabel('Frequency')

# Standard dev of the samples
std = np.std(sample_series)
# z-score for 90% confidence interval
z_score = 1.645
ci_range = z_score * std
print('90% Confident that the real product average lies within \n+-', \
      round(ci_range,2),f'from the observed average when the sample size is {num_ratings}')
# Out:
# 90% Confident that the real product average lies within
# +- 0.1 from the observed average when the sample size is 300

# %%
Note: maybe draw these are overlaping freuqency distributions for my final project

# %%
amazon25_df = pd.read_csv(r'rough_data\amazon_dataset\amzn_25plusreviews_final_format.csv')
amazon300_df = amazon25_df[:25776]

# %%
  
fig = plt.figure(figsize=(6,12))
fig.subplots_adjust(hspace=0, wspace=0.05)
ax = fig.add_subplot(2, 1, 2) # Start Plot 2
plt.hist(sample_series, bins=75, density=True, range=(1.0, 5.0), color='blue')
plt.title('')
plt.xlabel('Sample Average Rating')
plt.ylabel('Frequency')
ax.set_xlim(1,5)
plt.xlabel('Average Product Rating (out of 5)', fontsize=14)
ax.set_ylabel('')
ax.tick_params(axis='y', which='both', left=False, right=False, labelleft=False)
ax = fig.add_subplot(2, 1, 1)  # Start Plot 1
plt.hist(amazon300_df['average_rating'], bins=75, density=True, color='red')
plt.title('Product Average Ratings (Red) and Single-Product\nSample Average Ratings Distribution (Blue)', fontsize=16)
plt.xlabel('')
plt.ylabel('')
plt.xlim(1,5)
ax.tick_params(axis='y', which='both', left=False, right=False, labelleft=False)
plt.savefig('all_averages_to_sample_dist.png')
plt.savefig('all_averages_to_sample_dist.pdf')
plt.savefig('all_averages_to_sample_dist.jpg')
