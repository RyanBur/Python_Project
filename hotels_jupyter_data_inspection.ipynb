# %%
import numpy as np
import pandas as pd

# %%
hotels_df = pd.read_csv(r'rough_data\515k_hotel_reviews_in_europe\hotel_reviews.csv')

# %%
hotels_df
# Out:
#                                             Hotel_Address  \
# 0        s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 1        s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 2        s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 3        s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 4        s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# ...                                                   ...
# 515733  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515734  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515735  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515736  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515737  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
#
#         Additional_Number_of_Scoring Review_Date  Average_Score  \
# 0                                194    8/3/2017            7.7
# 1                                194    8/3/2017            7.7
# 2                                194   7/31/2017            7.7
# ...

# %%
hotels_df['Hotel_Address'].value_counts()
# Out:
# 163 Marsh Wall Docklands Tower Hamlets London E14 9SJ United Kingdom              4789
# 372 Strand Westminster Borough London WC2R 0JJ United Kingdom                     4256
# Westminster Bridge Road Lambeth London SE1 7UT United Kingdom                     4169
# Scarsdale Place Kensington Kensington and Chelsea London W8 5SY United Kingdom    3578
# 7 Pepys Street City of London London EC3N 4AF United Kingdom                      3212
#                                                                                   ...
# 2 4 Boundary Street Hackney London E2 7DD United Kingdom                            12
# Filmteichstra e 5 10 Favoriten 1100 Vienna Austria                                  12
# 13 Rue Fran ois Ory 92120 Paris France                                              10
# Via M Buonarroti 13 Fiera Milano City 20149 Milan Italy                             10
# Johann Staud Stra e 32 16 Ottakring 1160 Vienna Austria                              8
# ...

# %%
hotels_df['Hotel_Name'].value_counts()
# Out:
# Britannia International Hotel Canary Wharf           4789
# Strand Palace Hotel                                  4256
# Park Plaza Westminster Bridge London                 4169
# Copthorne Tara Hotel London Kensington               3578
# DoubleTree by Hilton Hotel London Tower of London    3212
#                                                      ...
# Hotel Daniel Paris                                     12
# Le Lavoisier                                           12
# Mercure Paris Porte d Orleans                          10
# Hotel Wagner                                           10
# Hotel Gallitzinberg                                     8
# Name: Hotel_Name, Length: 1492, dtype: int64

# %% [markdown]
# Number of unique Hotel_Name values only differs from number of uniqe Hotel_address values by 1 over the course of 1492 hotels, so I can use Hotel_Name as a unique identifier.
#
# There are 1492 unique hotels in the dataset, with a total of 515,738 reviews.

# %%
hotels_df.groupby('Hotel_Name')['Reviewer_Score'].agg(['mean','count']).sort_values('count', ascending=False)[:1081]
# Out:
#                                                        mean  count
# Hotel_Name
# Britannia International Hotel Canary Wharf         6.826644   4789
# Strand Palace Hotel                                8.128853   4256
# Park Plaza Westminster Bridge London               8.652866   4169
# Copthorne Tara Hotel London Kensington             8.094243   3578
# DoubleTree by Hilton Hotel London Tower of London  8.662765   3212
# ...                                                     ...    ...
# Bassano                                            8.131000    100
# Hotel Zeitgeist Vienna Hauptbahnhof                8.559000    100
# The Berkeley                                       9.064000    100
# Best Western Aulivia Op ra                         7.844000    100
# The Portobello Hotel                               9.032323     99
#
# [1081 rows x 2 columns]

# %% [markdown]
# 1080 Unique hotels have 100+ reviews.

# %%
hotels_df.groupby('Hotel_Name')['Reviewer_Score'].agg(['mean','count']).sort_values('count', ascending=False)[:1335]
# Out:
#                                                        mean  count
# Hotel_Name
# Britannia International Hotel Canary Wharf         6.826644   4789
# Strand Palace Hotel                                8.128853   4256
# Park Plaza Westminster Bridge London               8.652866   4169
# Copthorne Tara Hotel London Kensington             8.094243   3578
# DoubleTree by Hilton Hotel London Tower of London  8.662765   3212
# ...                                                     ...    ...
# Melia Paris Vendome                                8.298039     51
# Hotel Dieci                                        7.740000     50
# H tel des Academies et des Arts                    8.896000     50
# Ilunion Bel Art                                    8.134000     50
# Roomz Vienna                                       8.518367     49
#
# [1335 rows x 2 columns]

# %% [markdown]
# 1,334 Unique hotels have 50+ reviews

# %%
hotels_df.groupby('Hotel_Name')['Reviewer_Score'].agg(['mean','count']).sort_values('count', ascending=False)[:1446]
# Out:
#                                                        mean  count
# Hotel_Name
# Britannia International Hotel Canary Wharf         6.826644   4789
# Strand Palace Hotel                                8.128853   4256
# Park Plaza Westminster Bridge London               8.652866   4169
# Copthorne Tara Hotel London Kensington             8.094243   3578
# DoubleTree by Hilton Hotel London Tower of London  8.662765   3212
# ...                                                     ...    ...
# Hotel G tico                                       8.092000     25
# Mercure Paris 15 Porte de Versailles               7.828000     25
# Hotel Tour d Auvergne Opera                        8.476000     25
# Hotel Villa Lafayette Paris IX                     9.228000     25
# Goralska R sidences H tel Paris Bastille           9.458333     24
#
# [1446 rows x 2 columns]

# %% [markdown]
# 1,445 Unique hotels have 25+ reviews. This is nearly the whole dataset. Likely this dataset had some kind of sort or minimum criteria by reviews / property. Or maybe all luxury hotels have been reviewed at least tens of times.

# %%
hotels_df['Reviewer_Score'].mean()
# Out:
# 8.395076569886239

# %%
#Scale adjusts this 10-point system down to a more common 5-point ('star') system.
scale_adjustment = 5/10

adjusted_mean = hotels_df['Reviewer_Score'].mean() * scale_adjustment
adjusted_mean
# Out:
# 4.1975382849431195
